# %%
import re, nltk, csv, codecs, pickle
import pandas as pd
m = codecs.open('../data/master.csv', "r",encoding='utf-8', errors='ignore')
master = pd.read_csv(m)

train = master.sample(frac=0.8)
test = master.drop(train.index)

# %%
def processLine(line):
    
    #covert to lowercase
    line = line.lower()
    #convert www.* or https?://* to URL
    line = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', line)
    #convert @username to AT_USER
    line = re.sub('@[^\s]+', 'AT_USER', line)
    #remove addional white spaces
    line = re.sub('[\s]+', ' ', line)
    #replace #word with word
    line = re.sub(r'#([^\s]+)', r'\1', line)
    #trim
    line = line.strip('\'"')
    return line

# %%
trainTuples = [tuple(x) for x in master.values]
#trainTuples = [tuple(x) for x in train.values]
#testTuples = [tuple(x) for x in train.values]

# %%
#initialize stopWords
def getStopWordList(stopWordListFileName):
    stopwords = []
    stopWords.append('AT_USER')
    stopWords.append('URL')
    
    fp = open(stopWordListFileName, 'r')
    line = fp.readline()
    while line:
        word = line.strip()
        stopWords.append(word)
        line = fp.readline()
    fp.close()
    return stopWords

stopWords = []
st = open('../data/stopwords.txt', 'r')
stopWords = getStopWordList('../data/stopwords.txt')

#replace repetitions
def replaceTwoOrMore(s):
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", s)

def getTrainFeatureVector(line):
    featureVector = []
    words = line.split()
    negFound = 0
    for w in words:
        #replace two or more with two occurences
        w = replaceTwoOrMore(w)
        #strip punctuation
        w = w.strip('\'"?,.')
        #check if the word starts with a letter or number
        val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", w)
        #ignore if it is a stop word
        if(w in stopWords):
            continue
        else:
            featureVector.append(w.lower())
    return featureVector

def getFeatureVector(line):
    featureVector = []
    words = line.split()
    negFound = 0
    for w in words:
        #deal with negation
        if negFound == 1:
            if w == re.search('\?,.;', w):
                negFound == 0
            else:
                w = 'NOT_' + w
        if w == "not" or re.search(r"n't", w):
            negFound = 1
            
        #replace two or more with two occurences
        w = replaceTwoOrMore(w)
        #strip punctuation
        w = w.strip('\'"?,.')
        #check if the word starts with a letter or number
        val = re.search(r"^[a-zA-Z][a-zA-Z0-9]*$", w)
        #ignore if it is a stop word
        if(w in stopWords):
            continue
        else:
            featureVector.append(w.lower())
    return featureVector

# %%
#feature extraction
#read the lines one by one and process
featureList = []

lines = []
for t in trainTuples:
    line = t[0]
    sentiment = t[1]
    processedLine = processLine(line)
    print('processed line: ', processedLine)
    featureVector = getFeatureVector(processedLine)
    print('feature vector: ', featureVector)
    featureList.extend(featureVector)
    lines.append((featureVector, sentiment))

print(lines)
# Out:
# processed line:  good case, excellent value.
# feature vector:  ['good', 'excellent', 'value']
# processed line:  great for the jawbone.
# feature vector:  ['great', 'jawbone']
# processed line:  tied to charger for conversations lasting more than 45 minutes.major problems!!
# feature vector:  ['tied', 'charger', 'conversations', 'lasting', 'more', '45', 'minutes.major', 'problems!!']
# processed line:  the mic is great.
# feature vector:  ['mic', 'great']
# processed line:  i have to jiggle the plug to get it to line up right to get decent volume.
# feature vector:  ['i', 'jiggle', 'plug', 'get', 'line', 'up', 'right', 'get', 'decent', 'volume']
# processed line:  if you have several dozen or several hundred contacts, then imagine the fun of sending each of them one by one.
# feature vector:  ['you', 'several', 'dozen', 'several', 'hundred', 'contacts', 'imagine', 'fun', 'sending', 'each', 'one', 'one']
# processed line:  if you are razr owner...you must have this!
# feature vector:  ['you', 'razr', 'owner..you', 'must', 'this!']
# processed line:  needless to say, i wasted my money.
# feature vector:  ['needless', 'i', 'wasted', 'money']
# processed line:  what a waste of money and time!.
# feature vector:  ['what', 'waste', 'money', 'time!']
# processed line:  and the sound quality is great.
# feature vector:  ['sound', 'quality', 'great']
# processed line:  he was very impressed when going from the original battery to the extended battery.
# feature vector:  ['impressed', 'when', 'original', 'battery', 'extended', 'battery']
# processed line:  if the two were seperated by a mere 5+ ft i started to notice excessive static and garbled sound from the headset.
# feature vector:  ['seperated', 'mere', '5+', 'ft', 'i', 'started', 'notice', 'excessive', 'static', 'garbled', 'sound', 'headset']
# processed line:  very good quality though
# feature vector:  ['good', 'quality', 'though']
# processed line:  the design is very odd, as the ear "clip" is not very comfortable at all.
# feature vector:  ['design', 'odd', 'ear', 'clip', 'not', 'not_very', 'not_comfortable', 'not_at', 'not_all']
# processed line:  highly recommend for any one who has a blue tooth phone.
# feature vector:  ['highly', 'recommend', 'one', 'who', 'blue', 'tooth', 'phone']
# processed line:  i advise everyone do not be fooled!
# feature vector:  ['i', 'advise', 'everyone', 'not', 'not_be', 'not_fooled!']
# processed line:  so far so good!.
# feature vector:  ['far', 'good!']
# processed line:  works great!.
# feature vector:  ['works', 'great!']
# processed line:  it clicks into place in a way that makes you wonder how long that mechanism would last.
# feature vector:  ['clicks', 'makes', 'you', 'wonder', 'long', 'mechanism', 'last']
# processed line:  i went on motorola's website and followed all directions, but could not get it to pair again.
# feature vector:  ['i', "motorola's", 'website', 'followed', 'directions', 'not', 'not_get', 'not_it', 'not_to', 'not_pair', 'not_again']
# processed line:  i bought this to use with my kindle fire and absolutely loved it!
# feature vector:  ['i', 'bought', 'kindle', 'fire', 'absolutely', 'loved', 'it!']
# processed line:  the commercials are the most misleading.
# feature vector:  ['commercials', 'most', 'misleading']
# processed line:  i have yet to run this new battery below two bars and that's three days without charging.
# feature vector:  ['i', 'yet', 'run', 'new', 'battery', 'below', 'bars', "that's", 'days', 'without', 'charging']
# processed line:  i bought it for my mother and she had a problem with the battery.
# feature vector:  ['i', 'bought', 'mother', 'problem', 'battery']
# processed line:  great pocket pc / phone combination.
# feature vector:  ['great', 'pocket', 'pc', '/', 'phone', 'combination']
# processed line:  i've owned this phone for 7 months now and can say that it's the best mobile phone i've had.
# feature vector:  ["i've", 'owned', 'phone', '7', 'months', "it's", 'best', 'mobile', 'phone', "i've"]
# processed line:  i didn't think that the instructions provided were helpful to me.
# feature vector:  ['i', "didn't", 'not_think', 'not_that', 'not_the', 'not_instructions', 'not_provided', 'not_were', 'not_helpful', 'not_to', 'not_me']
# processed line:  people couldnt hear me talk and i had to pull out the earphone and talk on the phone.
# feature vector:  ['people', 'couldnt', 'hear', 'talk', 'i', 'pull', 'earphone', 'talk', 'phone']
# processed line:  doesn't hold charge.
# feature vector:  ["doesn't", 'not_hold', 'not_charge']
# processed line:  this is a simple little phone to use, but the breakage is unacceptible.
# feature vector:  ['simple', 'little', 'phone', 'breakage', 'unacceptible']
# processed line:  this product is ideal for people like me whose ears are very sensitive.
# feature vector:  ['product', 'ideal', 'people', 'like', 'whose', 'ears', 'sensitive']
# processed line:  it is unusable in a moving car at freeway speed.
# feature vector:  ['unusable', 'moving', 'car', 'freeway', 'speed']
# processed line:  i have two more years left in this contract and i hate this phone.
# feature vector:  ['i', 'more', 'years', 'left', 'contract', 'i', 'hate', 'phone']
# processed line:  car charger as well as ac charger are included to make sure you never run out of juice.highy recommended
# feature vector:  ['car', 'charger', 'well', 'ac', 'charger', 'included', 'you', 'never', 'run', 'juice.highy', 'recommended']
# processed line:  you need at least 3 mins to get to your phone book from the time you first turn on the phone.battery life is short.
# feature vector:  ['you', 'need', 'least', '3', 'mins', 'get', 'phone', 'book', 'time', 'you', 'first', 'turn', 'phone.battery', 'life', 'short']
# processed line:  it has kept up very well.
# feature vector:  ['kept', 'up', 'well']
# processed line:  poor talk time performance.
# feature vector:  ['poor', 'talk', 'time', 'performance']
# processed line:  the case is great and works fine with the 680.
# feature vector:  ['great', 'works', 'fine', '680']
# processed line:  worthless product.
# feature vector:  ['worthless', 'product']
# processed line:  it has a great camera thats 2mp, and the pics are nice and clear with great picture quality.
# feature vector:  ['great', 'camera', 'thats', '2mp', 'pics', 'nice', 'clear', 'great', 'picture', 'quality']
# processed line:  i was not impressed by this product.
# feature vector:  ['i', 'not', 'not_impressed', 'not_by', 'not_this', 'not_product']
# processed line:  nice headset priced right.
# feature vector:  ['nice', 'headset', 'priced', 'right']
# processed line:  i only hear garbage for audio.
# feature vector:  ['i', 'only', 'hear', 'garbage', 'audio']
# processed line:  excellent bluetooth headset.
# feature vector:  ['excellent', 'bluetooth', 'headset']
# processed line:  it has all the features i want
# feature vector:  ['features', 'i', 'want']
# processed line:  who in their right mind is gonna buy this battery?.
# feature vector:  ['who', 'right', 'mind', 'gonna', 'buy', 'battery']
# processed line:  after arguing with verizon regarding the dropped calls we returned the phones after two days.
# feature vector:  ['arguing', 'verizon', 'regarding', 'dropped', 'calls', 'returned', 'phones', 'days']
# processed line:  this case seems well made.
# feature vector:  ['seems', 'well']
# processed line:  disappointed with battery.
# feature vector:  ['disappointed', 'battery']
# processed line:  not loud enough and doesn't turn on like it should.
# feature vector:  ['not', 'not_loud', 'not_enough', 'not_and', "not_doesn't", 'not_turn', 'not_on', 'not_like', 'not_it', 'not_should']
# processed line:  good protection and does not make phone too bulky.
# feature vector:  ['good', 'protection', 'not', 'not_make', 'not_phone', 'not_too', 'not_bulky']
# processed line:  a usable keyboard actually turns a pda into a real-world useful machine instead of just a neat gadget.
# feature vector:  ['usable', 'keyboard', 'actually', 'turns', 'pda', 'real-world', 'useful', 'machine', 'instead', 'just', 'neat', 'gadget']
# processed line:  this phone is pretty sturdy and i've never had any large problems with it.
# feature vector:  ['phone', 'pretty', 'sturdy', "i've", 'never', 'large', 'problems']
# processed line:  i love this thing!
# feature vector:  ['i', 'love', 'thing!']
# processed line:  everything about it is fine and reasonable for the price i.e.
# feature vector:  ['everything', 'fine', 'reasonable', 'price', 'i.e']
# processed line:  very disappointed.
# feature vector:  ['disappointed']
# processed line:  i even dropped this phone into a stream and it was submerged for 15 seconds and it still works great!
# feature vector:  ['i', 'even', 'dropped', 'phone', 'stream', 'submerged', '15', 'seconds', 'still', 'works', 'great!']
# processed line:  i have been very happy with the 510 and have had no complaints from any one regarding my sound quality on their end.
# feature vector:  ['i', 'happy', '510', 'no', 'complaints', 'one', 'regarding', 'sound', 'quality', 'end']
# processed line:  the buttons for on and off are bad.
# feature vector:  ['buttons', 'off', 'bad']
# processed line:  essentially you can forget microsoft's tech support.
# feature vector:  ['essentially', 'you', 'forget', "microsoft's", 'tech', 'support']
# processed line:  i really recommend this faceplates since it looks very nice, elegant and cool.
# feature vector:  ['i', 'recommend', 'faceplates', 'since', 'looks', 'nice', 'elegant', 'cool']
# processed line:  these headphones were a great find - and i think they are perhaps the best purchase i've made in the last several years - seriously.
# feature vector:  ['headphones', 'great', 'find', '-', 'i', 'perhaps', 'best', 'purchase', "i've", 'last', 'several', 'years', '-', 'seriously']
# processed line:  buy a different phone - but not this.
# feature vector:  ['buy', 'different', 'phone', '-', 'not', 'not_this']
# processed line:  you have to hold the phone at a particular angle for the other party to hear you clearly.
# feature vector:  ['you', 'hold', 'phone', 'particular', 'angle', 'other', 'party', 'hear', 'you', 'clearly']
# processed line:  the one big drawback of the mp3 player is that the buttons on the phone's front cover that let you pause and skip songs lock out after a few seconds.
# feature vector:  ['one', 'big', 'drawback', 'mp3', 'player', 'buttons', "phone's", 'front', 'cover', 'you', 'pause', 'skip', 'songs', 'lock', 'few', 'seconds']
# processed line:  a week later after i activated it, it suddenly died.
# feature vector:  ['week', 'later', 'i', 'activated', 'suddenly', 'died']
# processed line:  it feels more comfortable than most headsets because i wear glasses and that gets in the way sometimes.
# feature vector:  ['feels', 'more', 'comfortable', 'most', 'headsets', 'i', 'wear', 'glasses', 'gets', 'sometimes']
# processed line:  great for ipods too.
# feature vector:  ['great', 'ipods']
# processed line:  this device is great in several situations:1.)
# feature vector:  ['device', 'great', 'several', 'situations:1.)']
# processed line:  mic doesn't work.
# feature vector:  ['mic', "doesn't", 'not_work']
# processed line:  even in my bmw 3 series which is fairly quiet, i have trouble hearing what the other person is saying.
# feature vector:  ['even', 'bmw', '3', 'series', 'which', 'fairly', 'quiet', 'i', 'trouble', 'hearing', 'what', 'other', 'person', 'saying']
# processed line:  great choice!
# feature vector:  ['great', 'choice!']
# processed line:  nice docking station for home or work.
# feature vector:  ['nice', 'docking', 'station', 'home', 'work']
# processed line:  this is a beautiful phone.
# feature vector:  ['beautiful', 'phone']
# processed line:  love this product.
# feature vector:  ['love', 'product']
# processed line:  do not buy for d807...wrongly advertised for d807.
# feature vector:  ['not', 'not_buy', 'not_for', 'not_d807..wrongly', 'not_advertised', 'not_for', 'not_d807']
# processed line:  this is a great little item.
# feature vector:  ['great', 'little', 'item']
# processed line:  i love this phone , it is very handy and has a lot of features .
# feature vector:  ['i', 'love', 'phone', '', 'handy', 'lot', 'features', '']
# processed line:  i purchased this and within 2 days it was no longer working!!!!!!!!!
# feature vector:  ['i', 'purchased', '2', 'days', 'no', 'longer', 'working!!']
# processed line:  i wear it everyday and it holds up very well.
# feature vector:  ['i', 'wear', 'everyday', 'holds', 'up', 'well']
# processed line:  not a good bargain.
# feature vector:  ['not', 'not_a', 'not_good', 'not_bargain']
# processed line:  well packaged, arrived on time, and works as intended.
# feature vector:  ['well', 'packaged', 'arrived', 'time', 'works', 'intended']
# processed line:  the battery runs down quickly.
# feature vector:  ['battery', 'runs', 'down', 'quickly']
# processed line:  this item worked great, but it broke after 6 months of use.
# feature vector:  ['item', 'worked', 'great', 'broke', '6', 'months']
# processed line:  the headsets are easy to use and everyone loves them.
# feature vector:  ['headsets', 'easy', 'everyone', 'loves']
# processed line:  this phone works great.
# feature vector:  ['phone', 'works', 'great']
# processed line:  the construction of the headsets is poor.
# feature vector:  ['construction', 'headsets', 'poor']
# processed line:  product was excellent and works better than the verizon one and boy was it cheaper!
# feature vector:  ['product', 'excellent', 'works', 'better', 'verizon', 'one', 'boy', 'cheaper!']
# processed line:  the phone loads super!
# feature vector:  ['phone', 'loads', 'super!']
# processed line:  for a product that costs as much as this one does, i expect it to work far better and with greater ease than this thing does.
# feature vector:  ['product', 'costs', 'much', 'one', 'i', 'expect', 'work', 'far', 'better', 'greater', 'ease']
# processed line:  made very sturdy.
# feature vector:  ['sturdy']
# processed line:  worked great!.
# feature vector:  ['worked', 'great!']
# processed line:  the ear buds only play music in one ear.
# feature vector:  ['ear', 'buds', 'only', 'play', 'music', 'one', 'ear']
# processed line:  dont waste your money...
# feature vector:  ['dont', 'waste', 'money']
# processed line:  will order from them again!
# feature vector:  ['will', 'again!']
# processed line:  if you plan to use this in a car forget about it.
# feature vector:  ['you', 'plan', 'car', 'forget']
# processed line:  i found this product to be waaay too big.
# feature vector:  ['i', 'found', 'product', 'waay', 'big']
# processed line:  best i've found so far .... i've tried 2 other bluetooths and this one has the best quality (for both me and the listener) as well as ease of using.
# feature vector:  ['best', "i've", 'found', 'far', '', "i've", 'tried', '2', 'other', 'bluetooths', 'one', 'best', 'quality', '(for', 'listener)', 'well', 'ease', 'using']
# processed line:  i'm very disappointed with my decision.
# feature vector:  ["i'm", 'disappointed', 'decision']
# processed line:  integrated seamlessly with the motorola razr phone.
# feature vector:  ['integrated', 'seamlessly', 'motorola', 'razr', 'phone']
# processed line:  buyer beware, you could flush money right down the toilet.
# feature vector:  ['buyer', 'beware', 'you', 'flush', 'money', 'right', 'down', 'toilet']
# processed line:  definitely a bargain.
# feature vector:  ['definitely', 'bargain']
# processed line:  the price was very good and with the free shipping and all it was a good purchase.
# feature vector:  ['price', 'good', 'free', 'shipping', 'good', 'purchase']
# processed line:  i received my supposedly new motorola 375 and apparently there was not a match between the phone and the charger.
# feature vector:  ['i', 'received', 'supposedly', 'new', 'motorola', '375', 'apparently', 'not', 'not_a', 'not_match', 'not_between', 'not_the', 'not_phone', 'not_and', 'not_the', 'not_charger']
# processed line:  pros:-good camera - very nice pictures , also has cool styles like black and white, and more.
# feature vector:  ['pros:-good', 'camera', '-', 'nice', 'pictures', '', 'cool', 'styles', 'like', 'black', 'white', 'more']
# processed line:  that's a huge design flaw (unless i'm not using it correctly, which i don't think is the case).
# feature vector:  ["that's", 'huge', 'design', 'flaw', '(unless', "i'm", 'not', 'not_using', 'not_it', 'not_correctly', 'not_which', 'not_i', "not_don't", 'not_think', 'not_is', 'not_the', 'not_case)']
# processed line:  i love my 350 headset.. my jabra350 bluetooth headset is great, the reception is very good and the ear piece is a comfortable fit.
# feature vector:  ['i', 'love', '350', 'headset', 'jabra350', 'bluetooth', 'headset', 'great', 'reception', 'good', 'ear', 'piece', 'comfortable', 'fit']
# processed line:  the camera, although rated at an impressive 1.3 megapixels, renders images that fall well below expectations of such a relatively high resolution.
# feature vector:  ['camera', 'although', 'rated', 'impressive', '1.3', 'megapixels', 'renders', 'images', 'fall', 'well', 'below', 'expectations', 'such', 'relatively', 'high', 'resolution']
# processed line:  i purcashed this for the car charger and it does not work.
# feature vector:  ['i', 'purcashed', 'car', 'charger', 'not', 'not_work']
# processed line:  sound quality on both end is excellent, i use headset to call my wife and ask my wife to use headset to call me !2.
# feature vector:  ['sound', 'quality', 'end', 'excellent', 'i', 'headset', 'call', 'wife', 'wife', 'headset', 'call', '!2']
# processed line:  this phone is slim and light and the display is beautiful.
# feature vector:  ['phone', 'slim', 'light', 'display', 'beautiful']
# processed line:  its a little geeky but i think thats its sex on toast and it rocks and oozes sex right down to its battery embedded sleek stylish leather case.
# feature vector:  ['little', 'geeky', 'i', 'thats', 'sex', 'toast', 'rocks', 'oozes', 'sex', 'right', 'down', 'battery', 'embedded', 'sleek', 'stylish', 'leather']
# processed line:  great product, fast shipping!.
# feature vector:  ['great', 'product', 'fast', 'shipping!']
# processed line:  absolutely great.
# feature vector:  ['absolutely', 'great']
# processed line:  the keyboard is a nice compromise between a full qwerty and the basic cell phone number keypad.
# feature vector:  ['keyboard', 'nice', 'compromise', 'full', 'qwerty', 'basic', 'cell', 'phone', 'keypad']
# processed line:  i got this phone around the end of may and i'm completely unhappy with it.
# feature vector:  ['i', 'got', 'phone', 'end', "i'm", 'completely', 'unhappy']
# processed line:  it is very comfortable on the ear.
# feature vector:  ['comfortable', 'ear']
# processed line:  it has been a winner for us.
# feature vector:  ['winner']
# processed line:  )setup couldn't have been simpler.
# feature vector:  [')setup', "couldn't", 'not_have', 'not_been', 'not_simpler']
# processed line:  i've tried several different earpieces for my cell phone and this jabra one is the first one i've found that fits my ear comfortably.
# feature vector:  ["i've", 'tried', 'several', 'different', 'earpieces', 'cell', 'phone', 'jabra', 'one', 'first', 'one', "i've", 'found', 'fits', 'ear', 'comfortably']
# processed line:  could not get strong enough signal.
# feature vector:  ['not', 'not_get', 'not_strong', 'not_enough', 'not_signal']
# processed line:  iam very pleased with my purchase.
# feature vector:  ['iam', 'pleased', 'purchase']
# processed line:  bad quality.
# feature vector:  ['bad', 'quality']
# processed line:  gets the job done.
# feature vector:  ['gets', 'job', 'done']
# processed line:  great audio!.
# feature vector:  ['great', 'audio!']
# processed line:  basically the service was very bad.
# feature vector:  ['basically', 'service', 'bad']
# processed line:  it did not work in my cell phone plug i am very up set with the charger!.
# feature vector:  ['not', 'not_work', 'not_in', 'not_my', 'not_cell', 'not_phone', 'not_plug', 'not_i', 'not_am', 'not_very', 'not_up', 'not_set', 'not_with', 'not_the', 'not_charger!']
# processed line:  i've only had my bluetooth for a few weeks, but i really like it.
# feature vector:  ["i've", 'only', 'bluetooth', 'few', 'weeks', 'i', 'like']
# processed line:  the bt headset was such a disapoinment.
# feature vector:  ['bt', 'headset', 'such', 'disapoinment']
# processed line:  it is so small and you don't even realize that it is there after a while of getting used to it.
# feature vector:  ['small', 'you', "don't", 'not_even', 'not_realize', 'not_that', 'not_it', 'not_is', 'not_there', 'not_after', 'not_a', 'not_while', 'not_of', 'not_getting', 'not_used', 'not_to', 'not_it']
# processed line:  the accompanied software is almost brilliant.
# feature vector:  ['accompanied', 'software', 'almost', 'brilliant']
# processed line:  headset works great & was packaged nicely to avoid any damage.
# feature vector:  ['headset', 'works', 'great', '&', 'packaged', 'nicely', 'avoid', 'damage']
# processed line:  !i definitly recommend!!
# feature vector:  ['!i', 'definitly', 'recommend!!']
# processed line:  buyer--be very careful!!!!!.
# feature vector:  ['buyer--be', 'careful!!']
# processed line:  the majority of the logitech earbud headsets failed.
# feature vector:  ['majority', 'logitech', 'earbud', 'headsets', 'failed']
# processed line:  very good stuff for the price.
# feature vector:  ['good', 'stuff', 'price']
# processed line:  my headset works just peachy-keen.
# feature vector:  ['headset', 'works', 'just', 'peachy-keen']
# processed line:  in my house i was getting dropped coverage upstairs and no coverage in my basement.
# feature vector:  ['house', 'i', 'getting', 'dropped', 'coverage', 'upstairs', 'no', 'coverage', 'basement']
# processed line:  voice recognition is tremendous!
# feature vector:  ['voice', 'recognition', 'tremendous!']
# processed line:  what a waste.
# feature vector:  ['what', 'waste']
# processed line:  during several different 2 minute calls, i experienced 5 drops and it was in an area that had 5 bars.
# feature vector:  ['several', 'different', '2', 'minute', 'calls', 'i', 'experienced', '5', 'drops', '5', 'bars']
# processed line:  i was not happy with this item.
# feature vector:  ['i', 'not', 'not_happy', 'not_with', 'not_this', 'not_item']
# processed line:  very disappointed.
# feature vector:  ['disappointed']
# processed line:  the phone takes forever to charge like 2 to 5 hours literally.
# feature vector:  ['phone', 'takes', 'forever', 'charge', 'like', '2', '5', 'hours', 'literally']
# processed line:  i got this phone on reccomendation from a relative and i'm glad i did.
# feature vector:  ['i', 'got', 'phone', 'reccomendation', 'relative', "i'm", 'glad', 'i']
# processed line:  what a waste of time!
# feature vector:  ['what', 'waste', 'time!']
# processed line:  its reception is very very poor.
# feature vector:  ['reception', 'poor']
# processed line:  items stated as included from the description are not included.
# feature vector:  ['items', 'stated', 'included', 'description', 'not', 'not_included']
# processed line:  after 3 months, screen just went black all of a sudden.
# feature vector:  ['3', 'months', 'screen', 'just', 'black', 'sudden']
# processed line:  i was hoping for more.
# feature vector:  ['i', 'hoping', 'more']
# processed line:  audio quality is poor, very poor.
# feature vector:  ['audio', 'quality', 'poor', 'poor']
# processed line:  i had absolutely no problem with this headset linking to my 8530 blackberry curve!
# feature vector:  ['i', 'absolutely', 'no', 'problem', 'headset', 'linking', '8530', 'blackberry', 'curve!']
# processed line:  i know that sounds funny, but to me it seemed like sketchy technology that wouldn't work well.well, this one works great.
# feature vector:  ['i', 'sounds', 'funny', 'seemed', 'like', 'sketchy', 'technology', "wouldn't", 'not_work', 'not_well.well', 'not_this', 'not_one', 'not_works', 'not_great']
# processed line:  i've bought $5 wired headphones that sound better than these.
# feature vector:  ["i've", 'bought', '$5', 'wired', 'headphones', 'sound', 'better']
# processed line:  this phone is very fast with sending any kind of messages and web browsing is significantly faster than previous phones i have used.
# feature vector:  ['phone', 'fast', 'sending', 'kind', 'messages', 'web', 'browsing', 'significantly', 'faster', 'previous', 'phones', 'i']
# processed line:  nice quality build, unlike some cheap s*** out there.
# feature vector:  ['nice', 'quality', 'build', 'unlike', 'cheap', 's**']
# processed line:  this item is fantastic and works perfectly!
# feature vector:  ['item', 'fantastic', 'works', 'perfectly!']
# processed line:  and i just love the colors!
# feature vector:  ['i', 'just', 'love', 'colors!']
# processed line:  w810i is just superb.
# feature vector:  ['w810i', 'just', 'superb']
# processed line:  all i can do is whine on the internet, so here it goes.the more i use the thing the less i like it.
# feature vector:  ['i', 'whine', 'internet', 'goes.the', 'more', 'i', 'less', 'i', 'like']
# processed line:  great charger.
# feature vector:  ['great', 'charger']
# processed line:  this is essentially a communications tool that does not communicate.
# feature vector:  ['essentially', 'communications', 'tool', 'not', 'not_communicate']
# processed line:  works like a charm; it work the same as the one i got with the phone.
# feature vector:  ['works', 'like', 'charm;', 'work', 'same', 'one', 'i', 'got', 'phone']
# processed line:  i still maintain that monkeys shouldn't make headphones, we just obviously don't share enough dna to copy the design over to humans.
# feature vector:  ['i', 'still', 'maintain', 'monkeys', "shouldn't", 'not_make', 'not_headphones', 'not_we', 'not_just', 'not_obviously', "not_don't", 'not_share', 'not_enough', 'not_dna', 'not_to', 'not_copy', 'not_the', 'not_design', 'not_over', 'not_to', 'not_humans']
# processed line:  great value.
# feature vector:  ['great', 'value']
# processed line:  doesn't work at all.. i bougth it for my l7c and its not working.
# feature vector:  ["doesn't", 'not_work', 'not_at', 'not_all', 'not_i', 'not_bougth', 'not_it', 'not_for', 'not_my', 'not_l7c', 'not_and', 'not_its', 'not_not', 'not_working']
# processed line:  the look of it is very sharp and the screen is nice and clear, with great graphics.
# feature vector:  ['look', 'sharp', 'screen', 'nice', 'clear', 'great', 'graphics']
# processed line:  doesn't last long.
# feature vector:  ["doesn't", 'not_last', 'not_long']
# processed line:  one thing i hate is the mode set button at the side.
# feature vector:  ['one', 'i', 'hate', 'mode', 'set', 'button']
# processed line:  excellent service!!!!!!!!.
# feature vector:  ['excellent', 'service!!']
# processed line:  thank you for wasting my money.
# feature vector:  ['thank', 'you', 'wasting', 'money']
# processed line:  how can that be?the audio quality is poor.
# feature vector:  ['be?the', 'audio', 'quality', 'poor']
# processed line:  the igo chargers and tips are really great.
# feature vector:  ['igo', 'chargers', 'tips', 'great']
# processed line:  the file browser offers all the options that one needs.handsfree is great.
# feature vector:  ['file', 'browser', 'offers', 'options', 'one', 'needs.handsfree', 'great']
# processed line:  superb phone on a great network.
# feature vector:  ['superb', 'phone', 'great', 'network']
# processed line:  i connected my wife's bluetooth,(motorola hs850) to my phone and it worked like a charm whether the phone was in my pocket or the case.
# feature vector:  ['i', 'connected', "wife's", 'bluetooth,(motorola', 'hs850)', 'phone', 'worked', 'like', 'charm', 'phone', 'pocket']
# processed line:  i put the latest os on it (v1.15g), and it now likes to slow to a crawl and lock up every once in a while.
# feature vector:  ['i', 'latest', 'os', '(v1.15g)', 'likes', 'slow', 'crawl', 'lock', 'up', 'every', 'once']
# processed line:  it only recognizes the phone as its storage device.
# feature vector:  ['only', 'recognizes', 'phone', 'storage', 'device']
# processed line:  if you like a loud buzzing to override all your conversations, then this phone is for you!
# feature vector:  ['you', 'like', 'loud', 'buzzing', 'override', 'conversations', 'phone', 'you!']
# processed line:  don't buy this product.
# feature vector:  ["don't", 'not_buy', 'not_this', 'not_product']
# processed line:  i've had this bluetoooth headset for some time now and still not comfortable with the way it fits on the ear.
# feature vector:  ["i've", 'bluetooth', 'headset', 'time', 'still', 'not', 'not_comfortable', 'not_with', 'not_the', 'not_way', 'not_it', 'not_fits', 'not_on', 'not_the', 'not_ear']
# processed line:  the sound quality is good and functionality is awesome.
# feature vector:  ['sound', 'quality', 'good', 'functionality', 'awesome']
# processed line:  i have this phone and it is a thorn in my side, i really abhor it.
# feature vector:  ['i', 'phone', 'thorn', 'i', 'abhor']
# processed line:  i recently had problems where i could not stay connected for more than 10 minutes before being disconnected.
# feature vector:  ['i', 'recently', 'problems', 'where', 'i', 'not', 'not_stay', 'not_connected', 'not_for', 'not_more', 'not_than', 'not_10', 'not_minutes', 'not_before', 'not_being', 'not_disconnected']
# processed line:  incredible!.
# feature vector:  ['incredible!']
# processed line:  design flaw?.
# feature vector:  ['design', 'flaw']
# processed line:  great phone!.
# feature vector:  ['great', 'phone!']
# processed line:  waste of 13 bucks.
# feature vector:  ['waste', '13', 'bucks']
# processed line:  but when i check voice mail at night, the keypad backlight turns off a few seconds into the first message, and then i'm lost.
# feature vector:  ['when', 'i', 'check', 'voice', 'mail', 'night', 'keypad', 'backlight', 'turns', 'off', 'few', 'seconds', 'first', 'message', "i'm", 'lost']
# processed line:  the replacement died in a few weeks.
# feature vector:  ['replacement', 'died', 'few', 'weeks']
# processed line:  any ring tone..overall good phone to buy..
# feature vector:  ['ring', 'tone..overall', 'good', 'phone', 'buy']
# processed line:  lately they have been extremely nice and helpful on the phone.
# feature vector:  ['lately', 'extremely', 'nice', 'helpful', 'phone']
# processed line:  i have had problems wit hit dropping signal and more.
# feature vector:  ['i', 'problems', 'wit', 'hit', 'dropping', 'signal', 'more']
# processed line:  not impressed.
# feature vector:  ['not', 'not_impressed']
# processed line:  light weight, i hardly notice it is there.
# feature vector:  ['light', 'weight', 'i', 'hardly', 'notice']
# processed line:  you'll love how thin it is.
# feature vector:  ["you'll", 'love', 'thin']
# processed line:  bad choice.
# feature vector:  ['bad', 'choice']
# processed line:  the pleather case doesn't fit.
# feature vector:  ['pleather', "doesn't", 'not_fit']
# processed line:  useless phone, simply deaf.
# feature vector:  ['useless', 'phone', 'simply', 'deaf']
# processed line:  the color is even prettier than i thought it would be, and the graphics are incredibly sharp.
# feature vector:  ['color', 'even', 'prettier', 'i', 'graphics', 'incredibly', 'sharp']
# processed line:  all in all i think it was a good investment.
# feature vector:  ['i', 'good', 'investment']
# processed line:  it makes very strange ticking noises before it ends the call.
# feature vector:  ['makes', 'strange', 'ticking', 'noises', 'ends', 'call']
# processed line:  the best electronics of the available fm transmitters.
# feature vector:  ['best', 'electronics', 'available', 'fm', 'transmitters']
# processed line:  battery lasts only a few hours.
# feature vector:  ['battery', 'lasts', 'only', 'few', 'hours']
# processed line:  great headset, very impressed - h500.
# feature vector:  ['great', 'headset', 'impressed', '-', 'h500']
# processed line:  the "1.2" mega pixel camera, being a part of a phone, is reasonably good7.
# feature vector:  ['1.2', 'mega', 'pixel', 'camera', 'phone', 'reasonably', 'good7']
# processed line:  i've had this for nearly 2 years and it has worked great for me.
# feature vector:  ["i've", 'nearly', '2', 'years', 'worked', 'great']
# processed line:  good transmit audio.
# feature vector:  ['good', 'transmit', 'audio']
# processed line:  we are sending it back.
# feature vector:  ['sending', 'back']
# processed line:  i did not bother contacting the company for few dollar product but i learned the lesson that i should not have bought this form online anyway.
# feature vector:  ['i', 'not', 'not_bother', 'not_contacting', 'not_the', 'not_company', 'not_for', 'not_few', 'not_dollar', 'not_product', 'not_but', 'not_i', 'not_learned', 'not_the', 'not_lesson', 'not_that', 'not_i', 'not_should', 'not_not', 'not_have', 'not_bought', 'not_this', 'not_form', 'not_online', 'not_anyway']
# processed line:  if you hate earbugs, avoid this phone by all means.
# feature vector:  ['you', 'hate', 'earbugs', 'avoid', 'phone', 'means']
# processed line:  great price also!
# feature vector:  ['great', 'price', 'also!']
# processed line:  the range is very decent, i've been able to roam around my house with the phone in the living room with no reception/sound quality issues.
# feature vector:  ['range', 'decent', "i've", 'able', 'roam', 'house', 'phone', 'living', 'no', 'reception/sound', 'quality', 'issues']
# processed line:  fast service.
# feature vector:  ['fast', 'service']
# processed line:  i would highly recommend this.
# feature vector:  ['i', 'highly', 'recommend']
# processed line:  i would recommend this.
# feature vector:  ['i', 'recommend']
# processed line:  i also didn't like the "on" button, it felt like it would crack with use.
# feature vector:  ['i', "didn't", 'not_like', 'not_the', 'not_"on', 'not_button', 'not_it', 'not_felt', 'not_like', 'not_it', 'not_would', 'not_crack', 'not_with', 'not_use']
# processed line:  worst phone ever.
# feature vector:  ['worst', 'phone', 'ever']
# processed line:  i'm still infatuated with this phone.
# feature vector:  ["i'm", 'still', 'infatuated', 'phone']
# processed line:  freezes frequently4.
# feature vector:  ['freezes', 'frequently4']
# processed line:  it's kind of embarrassing to use because of how it looks and mostly it's embarrassing how child-like the company is.
# feature vector:  ["it's", 'kind', 'embarrassing', 'looks', 'mostly', "it's", 'embarrassing', 'child-like', 'company']
# processed line:  simple, lightweight and great fit.
# feature vector:  ['simple', 'lightweight', 'great', 'fit']
# processed line:  all in all, i'd expected a better consumer experience from motorola.
# feature vector:  ["i'd", 'expected', 'better', 'consumer', 'experience', 'motorola']
# processed line:  there's a horrible tick sound in the background on all my calls that i have never experienced before.
# feature vector:  ["there's", 'horrible', 'tick', 'sound', 'background', 'calls', 'i', 'never', 'experienced']
# processed line:  these are certainly very comfortable and functionality is decent.
# feature vector:  ['certainly', 'comfortable', 'functionality', 'decent']
# processed line:  i usually don't like headbands but this one is very lightweight & doesn't mess up my hair.
# feature vector:  ['i', 'usually', "don't", 'not_like', 'not_headbands', 'not_but', 'not_this', 'not_one', 'not_is', 'not_very', 'not_lightweight', 'not_&', "not_doesn't", 'not_mess', 'not_up', 'not_my', 'not_hair']
# processed line:  i'm a bit disappointed.
# feature vector:  ["i'm", 'bit', 'disappointed']
# processed line:  i have had this phone for over a year now, and i will tell you, its not that great.
# feature vector:  ['i', 'phone', 'over', 'year', 'i', 'will', 'tell', 'you', 'not', 'not_that', 'not_great']
# processed line:  i ordered this for sony ericsson w810i but i think it only worked once (thats when i first used it).
# feature vector:  ['i', 'sony', 'ericsson', 'w810i', 'i', 'only', 'worked', 'once', '(thats', 'when', 'i', 'first', 'it)']
# processed line:  the battery is completely useless to me.
# feature vector:  ['battery', 'completely', 'useless']
# processed line:  what a big waste of time.
# feature vector:  ['what', 'big', 'waste', 'time']
# processed line:  don't waste your $$$ on this one.
# feature vector:  ["don't", 'not_waste', 'not_your', 'not_$$', 'not_on', 'not_this', 'not_one']
# processed line:  great sound and service.
# feature vector:  ['great', 'sound', 'service']
# processed line:  really pleased with this product so far.
# feature vector:  ['pleased', 'product', 'far']
# processed line:  one of my favorite purchases ever.
# feature vector:  ['one', 'favorite', 'purchases', 'ever']
# processed line:  best bluetooth on the market.
# feature vector:  ['best', 'bluetooth', 'market']
# processed line:  authentic leather with nice shine and comfort .i recommend you this case !!
# feature vector:  ['authentic', 'leather', 'nice', 'shine', 'comfort', 'i', 'recommend', 'you', '!!']
# processed line:  i was very excited to get this headset because i thought it was really cute.
# feature vector:  ['i', 'excited', 'get', 'headset', 'i', 'cute']
# processed line:  do not make the same mistake as me.
# feature vector:  ['not', 'not_make', 'not_the', 'not_same', 'not_mistake', 'not_as', 'not_me']
# processed line:  big disappointment with calendar sync.
# feature vector:  ['big', 'disappointment', 'calendar', 'sync']
# processed line:  the phone was unusable and was not new.
# feature vector:  ['phone', 'unusable', 'not', 'not_new']
# processed line:  worst customer service ever.
# feature vector:  ['worst', 'customer', 'service', 'ever']
# processed line:  no additional ear gels provided, and no instructions whatsoever.
# feature vector:  ['no', 'additional', 'ear', 'gels', 'provided', 'no', 'instructions', 'whatsoever']
# processed line:  it defeats the purpose of a bluetooth headset.
# feature vector:  ['defeats', 'purpose', 'bluetooth', 'headset']
# processed line:  worth every penny.
# feature vector:  ['worth', 'every', 'penny']
# processed line:  excellent wallet type phone case.
# feature vector:  ['excellent', 'wallet', 'type', 'phone']
# processed line:  nice headphones for the price and they work great!
# feature vector:  ['nice', 'headphones', 'price', 'work', 'great!']
# processed line:  internet is excrutiatingly slow.
# feature vector:  ['internet', 'excrutiatingly', 'slow']
# processed line:  it is very comfortable to wear as well, which is probably the most important aspect about using a case.
# feature vector:  ['comfortable', 'wear', 'well', 'which', 'probably', 'most', 'important', 'aspect', 'using']
# processed line:  it's fits like a glove and is strong, secure, and durable.
# feature vector:  ["it's", 'fits', 'like', 'glove', 'strong', 'secure', 'durable']
# processed line:  o my gosh the best phone i have ever had.
# feature vector:  ['gosh', 'best', 'phone', 'i', 'ever']
# processed line:  it's very attractive and appears to be of good quality.
# feature vector:  ["it's", 'attractive', 'appears', 'good', 'quality']
# processed line:  i love all the features and form factor.
# feature vector:  ['i', 'love', 'features', 'form', 'factor']
# processed line:  this product had a strong rubber/petroleum smell that was unbearable after a while and caused me to return it
# feature vector:  ['product', 'strong', 'rubber/petroleum', 'smell', 'unbearable', 'caused', 'return']
# processed line:  poor quality and service.
# feature vector:  ['poor', 'quality', 'service']
# processed line:  the cable looks so thin and flimsy, it is scary.
# feature vector:  ['cable', 'looks', 'thin', 'flimsy', 'scary']
# processed line:  great earpiece.
# feature vector:  ['great', 'earpiece']
# processed line:  excellent hands free tool.
# feature vector:  ['excellent', 'hands', 'free', 'tool']
# processed line:  great for using with your home stereo.
# feature vector:  ['great', 'using', 'home', 'stereo']
# processed line:  good product - incredible value.
# feature vector:  ['good', 'product', '-', 'incredible', 'value']
# processed line:  only had this a month but it's worked flawlessly so far.
# feature vector:  ['only', 'month', "it's", 'worked', 'flawlessly', 'far']
# processed line:  works great.
# feature vector:  ['works', 'great']
# processed line:  absolutel junk.
# feature vector:  ['absolutel', 'junk']
# processed line:  that one didn't work either.
# feature vector:  ['one', "didn't", 'not_work', 'not_either']
# processed line:  battery life is real good.
# feature vector:  ['battery', 'life', 'real', 'good']
# processed line:  returned 8 hours later.
# feature vector:  ['returned', '8', 'hours', 'later']
# processed line:  it's a great item.
# feature vector:  ["it's", 'great', 'item']
# processed line:  don't waste your money!.
# feature vector:  ["don't", 'not_waste', 'not_your', 'not_money!']
# processed line:  love this headset!
# feature vector:  ['love', 'headset!']
# processed line:  not only will it drain your player, but may also potentially fry it.
# feature vector:  ['not', 'not_only', 'not_will', 'not_it', 'not_drain', 'not_your', 'not_player', 'not_but', 'not_may', 'not_also', 'not_potentially', 'not_fry', 'not_it']
# processed line:  worked perfectly!
# feature vector:  ['worked', 'perfectly!']
# processed line:  unreliable - i'm giving up.
# feature vector:  ['unreliable', '-', "i'm", 'giving', 'up']
# processed line:  i gave it 5 stars because of the sound quality.
# feature vector:  ['i', 'gave', '5', 'stars', 'sound', 'quality']
# processed line:  avoid this one if you can.
# feature vector:  ['avoid', 'one', 'you']
# processed line:  reversible plug works great.
# feature vector:  ['reversible', 'plug', 'works', 'great']
# processed line:  i wasted my little money with this earpiece.
# feature vector:  ['i', 'wasted', 'little', 'money', 'earpiece']
# processed line:  very good phone.
# feature vector:  ['good', 'phone']
# processed line:  best of all is the rotating feature, very helpful.
# feature vector:  ['best', 'rotating', 'feature', 'helpful']
# processed line:  comfort for our whole family.
# feature vector:  ['comfort', 'whole', 'family']
# processed line:  good product, good seller.
# feature vector:  ['good', 'product', 'good', 'seller']
# processed line:  i love this bluetooth!
# feature vector:  ['i', 'love', 'bluetooth!']
# processed line:  first of all, it doesn't wear well.
# feature vector:  ['first', "doesn't", 'not_wear', 'not_well']
# processed line:  i am very impressed with this headset from plantronics.
# feature vector:  ['i', 'am', 'impressed', 'headset', 'plantronics']
# processed line:  i got it because it was so small and adorable.
# feature vector:  ['i', 'got', 'small', 'adorable']
# processed line:  great phone!.
# feature vector:  ['great', 'phone!']
# processed line:  i wouldn't recommend buying this product.
# feature vector:  ['i', "wouldn't", 'not_recommend', 'not_buying', 'not_this', 'not_product']
# processed line:  piece of junk.
# feature vector:  ['piece', 'junk']
# processed line:  poorly contstruct hinge.
# feature vector:  ['poorly', 'contstruct', 'hinge']
# processed line:  this item is great, installed it, let it charged up overnite and it has been working good every since with no problems
# feature vector:  ['item', 'great', 'installed', 'charged', 'up', 'overnite', 'working', 'good', 'every', 'since', 'no', 'problems']
# processed line:  great phone.
# feature vector:  ['great', 'phone']
# processed line:  don't buy it.
# feature vector:  ["don't", 'not_buy', 'not_it']
# processed line:  excellent phone.
# feature vector:  ['excellent', 'phone']
# processed line:  do not purchase this phone.
# feature vector:  ['not', 'not_purchase', 'not_this', 'not_phone']
# processed line:  the voice recognition thru the handset is excellent.
# feature vector:  ['voice', 'recognition', 'thru', 'handset', 'excellent']
# processed line:  this is hands down the best phone i've ever had.
# feature vector:  ['hands', 'down', 'best', 'phone', "i've", 'ever']
# processed line:  works great, when my cat attacked the phone he scratched the protective strip instead of destroying the screen.
# feature vector:  ['works', 'great', 'when', 'cat', 'attacked', 'phone', 'scratched', 'protective', 'strip', 'instead', 'destroying', 'screen']
# processed line:  this one works and was priced right.
# feature vector:  ['one', 'works', 'priced', 'right']
# processed line:  customer service was terrible.
# feature vector:  ['customer', 'service', 'terrible']
# processed line:  battery life still not long enough in motorola razor v3i.
# feature vector:  ['battery', 'life', 'still', 'not', 'not_long', 'not_enough', 'not_in', 'not_motorola', 'not_razor', 'not_v3i']
# processed line:  sending it back.
# feature vector:  ['sending', 'back']
# processed line:  now i know that i made a wise decision.
# feature vector:  ['i', 'i', 'wise', 'decision']
# processed line:  someone shouldve invented this sooner.
# feature vector:  ['shouldve', 'invented', 'sooner']
# processed line:  good price.
# feature vector:  ['good', 'price']
# processed line:  everything worked on the first try.the device was certainly engineered in a clever way and the construction feels good.
# feature vector:  ['everything', 'worked', 'first', 'try.the', 'device', 'certainly', 'engineered', 'clever', 'construction', 'feels', 'good']
# processed line:  i received it quickly and it works great!!
# feature vector:  ['i', 'received', 'quickly', 'works', 'great!!']
# processed line:  has been working great.
# feature vector:  ['working', 'great']
# processed line:  as many people complained, i found this headset's microphone was very weak.
# feature vector:  ['people', 'complained', 'i', 'found', "headset's", 'microphone', 'weak']
# processed line:  my 5-year old nokia 2160 from tracfone holds the charge a lot better than this.
# feature vector:  ['5-year', 'old', 'nokia', '2160', 'tracfone', 'holds', 'charge', 'lot', 'better']
# processed line:  they do not care about the consumer one bit.
# feature vector:  ['not', 'not_care', 'not_about', 'not_the', 'not_consumer', 'not_one', 'not_bit']
# processed line:  this is a good battery, and it got here really fast.
# feature vector:  ['good', 'battery', 'got', 'fast']
# processed line:  the instruction manual is lacking.
# feature vector:  ['instruction', 'manual', 'lacking']
# processed line:  also its slim enough to fit into my alarm clock docking station without removing the case.
# feature vector:  ['slim', 'enough', 'fit', 'alarm', 'clock', 'docking', 'station', 'without', 'removing']
# processed line:  phone now holds charge like it did when it was new.
# feature vector:  ['phone', 'holds', 'charge', 'like', 'when', 'new']
# processed line:  the battery is unreliable as well as the service use antena.
# feature vector:  ['battery', 'unreliable', 'well', 'service', 'antena']
# processed line:  it's uncomfortable and the sound quality is quite poor compared with the phone (razr) or with my previous wired headset (that plugged into an lg).
# feature vector:  ["it's", 'uncomfortable', 'sound', 'quality', 'quite', 'poor', 'compared', 'phone', '(razr)', 'previous', 'wired', 'headset', '(that', 'plugged', 'lg)']
# processed line:  we have gotten a lot of compliments on it.
# feature vector:  ['gotten', 'lot', 'compliments']
# processed line:  this is definitely a must have if your state does not allow cell phone usage while driving.
# feature vector:  ['definitely', 'must', 'not', 'not_allow', 'not_cell', 'not_phone', 'not_usage', 'not_while', 'not_driving']
# processed line:  i want my money back.
# feature vector:  ['i', 'want', 'money', 'back']
# processed line:  i love this device.
# feature vector:  ['i', 'love', 'device']
# processed line:  i am also very happy with the price.
# feature vector:  ['i', 'am', 'happy', 'price']
# processed line:  i ordered this product first and was unhappy with it immediately.
# feature vector:  ['i', 'product', 'first', 'unhappy', 'immediately']
# processed line:  the ngage is still lacking in earbuds.
# feature vector:  ['ngage', 'still', 'lacking', 'earbuds']
# processed line:  i was able to do voice dialing in the car with no problem.
# feature vector:  ['i', 'able', 'voice', 'dialing', 'car', 'no', 'problem']
# processed line:  i have 2-3 bars on my cell phone when i am home, but you cant not hear anything.
# feature vector:  ['i', '2-3', 'bars', 'cell', 'phone', 'when', 'i', 'am', 'home', 'you', 'cant', 'not', 'not_hear', 'not_anything']
# processed line:  good item, low price.
# feature vector:  ['good', 'item', 'low', 'price']
# processed line:  however-the riingtones are not the best, and neither are the games.
# feature vector:  ['however-the', 'riingtones', 'not', 'not_the', 'not_best', 'not_and', 'not_neither', 'not_are', 'not_the', 'not_games']
# processed line:  the plug did not work very well.
# feature vector:  ['plug', 'not', 'not_work', 'not_very', 'not_well']
# processed line:  amazon sucks.
# feature vector:  ['amazon', 'sucks']
# processed line:  rip off---- over charge shipping.
# ...
# feature vector:  ['thoughtfulness']
# processed line:  thrift
# feature vector:  ['thrift']
# processed line:  thrifty
# feature vector:  ['thrifty']
# processed line:  thrill
# feature vector:  ['thrill']
# processed line:  thrilled
# feature vector:  ['thrilled']
# processed line:  thrilling
# feature vector:  ['thrilling']
# processed line:  thrillingly
# feature vector:  ['thrillingly']
# processed line:  thrills
# feature vector:  ['thrills']
# processed line:  thrive
# feature vector:  ['thrive']
# processed line:  thriving
# feature vector:  ['thriving']
# processed line:  thumb-up
# feature vector:  ['thumb-up']
# processed line:  thumbs-up
# feature vector:  ['thumbs-up']
# processed line:  tickle
# feature vector:  ['tickle']
# processed line:  tidy
# feature vector:  ['tidy']
# processed line:  time-honored
# feature vector:  ['time-honored']
# processed line:  timely
# feature vector:  ['timely']
# processed line:  tingle
# feature vector:  ['tingle']
# processed line:  titillate
# feature vector:  ['titillate']
# processed line:  titillating
# feature vector:  ['titillating']
# processed line:  titillatingly
# feature vector:  ['titillatingly']
# processed line:  togetherness
# feature vector:  ['togetherness']
# processed line:  tolerable
# feature vector:  ['tolerable']
# processed line:  toll-free
# feature vector:  ['toll-free']
# processed line:  top
# feature vector:  ['top']
# processed line:  top-notch
# feature vector:  ['top-notch']
# processed line:  top-quality
# feature vector:  ['top-quality']
# processed line:  topnotch
# feature vector:  ['topnotch']
# processed line:  tops
# feature vector:  ['tops']
# processed line:  tough
# feature vector:  ['tough']
# processed line:  tougher
# feature vector:  ['tougher']
# processed line:  toughest
# feature vector:  ['toughest']
# processed line:  traction
# feature vector:  ['traction']
# processed line:  tranquil
# feature vector:  ['tranquil']
# processed line:  tranquility
# feature vector:  ['tranquility']
# processed line:  transparent
# feature vector:  ['transparent']
# processed line:  treasure
# feature vector:  ['treasure']
# processed line:  tremendously
# feature vector:  ['tremendously']
# processed line:  trendy
# feature vector:  ['trendy']
# processed line:  triumph
# feature vector:  ['triumph']
# processed line:  triumphal
# feature vector:  ['triumphal']
# processed line:  triumphant
# feature vector:  ['triumphant']
# processed line:  triumphantly
# feature vector:  ['triumphantly']
# processed line:  trivially
# feature vector:  ['trivially']
# processed line:  trophy
# feature vector:  ['trophy']
# processed line:  trouble-free
# feature vector:  ['trouble-free']
# processed line:  trump
# feature vector:  ['trump']
# processed line:  trumpet
# feature vector:  ['trumpet']
# processed line:  trust
# feature vector:  ['trust']
# processed line:  trusted
# feature vector:  ['trusted']
# processed line:  trusting
# feature vector:  ['trusting']
# processed line:  trustingly
# feature vector:  ['trustingly']
# processed line:  trustworthiness
# feature vector:  ['trustworthiness']
# processed line:  trustworthy
# feature vector:  ['trustworthy']
# processed line:  trusty
# feature vector:  ['trusty']
# processed line:  truthful
# feature vector:  ['truthful']
# processed line:  truthfully
# feature vector:  ['truthfully']
# processed line:  truthfulness
# feature vector:  ['truthfulness']
# processed line:  twinkly
# feature vector:  ['twinkly']
# processed line:  ultra-crisp
# feature vector:  ['ultra-crisp']
# processed line:  unabashed
# feature vector:  ['unabashed']
# processed line:  unabashedly
# feature vector:  ['unabashedly']
# processed line:  unaffected
# feature vector:  ['unaffected']
# processed line:  unassailable
# feature vector:  ['unassailable']
# processed line:  unbeatable
# feature vector:  ['unbeatable']
# processed line:  unbiased
# feature vector:  ['unbiased']
# processed line:  unbound
# feature vector:  ['unbound']
# processed line:  uncomplicated
# feature vector:  ['uncomplicated']
# processed line:  unconditional
# feature vector:  ['unconditional']
# processed line:  undamaged
# feature vector:  ['undamaged']
# processed line:  undaunted
# feature vector:  ['undaunted']
# processed line:  understandable
# feature vector:  ['understandable']
# processed line:  undisputable
# feature vector:  ['undisputable']
# processed line:  undisputably
# feature vector:  ['undisputably']
# processed line:  undisputed
# feature vector:  ['undisputed']
# processed line:  unencumbered
# feature vector:  ['unencumbered']
# processed line:  unequivocal
# feature vector:  ['unequivocal']
# processed line:  unequivocally
# feature vector:  ['unequivocally']
# processed line:  unfazed
# feature vector:  ['unfazed']
# processed line:  unfettered
# feature vector:  ['unfettered']
# processed line:  unforgettable
# feature vector:  ['unforgettable']
# processed line:  unity
# feature vector:  ['unity']
# processed line:  unlimited
# feature vector:  ['unlimited']
# processed line:  unmatched
# feature vector:  ['unmatched']
# processed line:  unparalleled
# feature vector:  ['unparalleled']
# processed line:  unquestionable
# feature vector:  ['unquestionable']
# processed line:  unquestionably
# feature vector:  ['unquestionably']
# processed line:  unreal
# feature vector:  ['unreal']
# processed line:  unrestricted
# feature vector:  ['unrestricted']
# processed line:  unrivaled
# feature vector:  ['unrivaled']
# processed line:  unselfish
# feature vector:  ['unselfish']
# processed line:  unwavering
# feature vector:  ['unwavering']
# processed line:  upbeat
# feature vector:  ['upbeat']
# processed line:  upgradable
# feature vector:  ['upgradable']
# processed line:  upgradeable
# feature vector:  ['upgradeable']
# processed line:  upgraded
# feature vector:  ['upgraded']
# processed line:  upheld
# feature vector:  ['upheld']
# processed line:  uphold
# feature vector:  ['uphold']
# processed line:  uplift
# feature vector:  ['uplift']
# processed line:  uplifting
# feature vector:  ['uplifting']
# processed line:  upliftingly
# feature vector:  ['upliftingly']
# processed line:  upliftment
# feature vector:  ['upliftment']
# processed line:  upscale
# feature vector:  ['upscale']
# processed line:  usable
# feature vector:  ['usable']
# processed line:  useable
# feature vector:  ['useable']
# processed line:  useful
# feature vector:  ['useful']
# processed line:  user-friendly
# feature vector:  ['user-friendly']
# processed line:  user-replaceable
# feature vector:  ['user-replaceable']
# processed line:  valiant
# feature vector:  ['valiant']
# processed line:  valiantly
# feature vector:  ['valiantly']
# processed line:  valor
# feature vector:  ['valor']
# processed line:  valuable
# feature vector:  ['valuable']
# processed line:  variety
# feature vector:  ['variety']
# processed line:  venerate
# feature vector:  ['venerate']
# processed line:  verifiable
# feature vector:  ['verifiable']
# processed line:  veritable
# feature vector:  ['veritable']
# processed line:  versatile
# feature vector:  ['versatile']
# processed line:  versatility
# feature vector:  ['versatility']
# processed line:  vibrant
# feature vector:  ['vibrant']
# processed line:  vibrantly
# feature vector:  ['vibrantly']
# processed line:  victorious
# feature vector:  ['victorious']
# processed line:  victory
# feature vector:  ['victory']
# processed line:  viewable
# feature vector:  ['viewable']
# processed line:  vigilance
# feature vector:  ['vigilance']
# processed line:  vigilant
# feature vector:  ['vigilant']
# processed line:  virtue
# feature vector:  ['virtue']
# processed line:  virtuous
# feature vector:  ['virtuous']
# processed line:  virtuously
# feature vector:  ['virtuously']
# processed line:  visionary
# feature vector:  ['visionary']
# processed line:  vivacious
# feature vector:  ['vivacious']
# processed line:  vivid
# feature vector:  ['vivid']
# processed line:  vouch
# feature vector:  ['vouch']
# processed line:  vouchsafe
# feature vector:  ['vouchsafe']
# processed line:  warm
# feature vector:  ['warm']
# processed line:  warmer
# feature vector:  ['warmer']
# processed line:  warmhearted
# feature vector:  ['warmhearted']
# processed line:  warmly
# feature vector:  ['warmly']
# processed line:  warmth
# feature vector:  ['warmth']
# processed line:  wealthy
# feature vector:  ['wealthy']
# processed line:  welcome
# feature vector:  ['welcome']
# processed line:  well
# feature vector:  ['well']
# processed line:  well-backlit
# feature vector:  ['well-backlit']
# processed line:  well-balanced
# feature vector:  ['well-balanced']
# processed line:  well-behaved
# feature vector:  ['well-behaved']
# processed line:  well-being
# feature vector:  ['well-being']
# processed line:  well-bred
# feature vector:  ['well-bred']
# processed line:  well-connected
# feature vector:  ['well-connected']
# processed line:  well-educated
# feature vector:  ['well-educated']
# processed line:  well-established
# feature vector:  ['well-established']
# processed line:  well-informed
# feature vector:  ['well-informed']
# processed line:  well-intentioned
# feature vector:  ['well-intentioned']
# processed line:  well-known
# feature vector:  ['well-known']
# processed line:  well-made
# feature vector:  ['well-made']
# processed line:  well-managed
# feature vector:  ['well-managed']
# processed line:  well-mannered
# feature vector:  ['well-mannered']
# processed line:  well-positioned
# feature vector:  ['well-positioned']
# processed line:  well-received
# feature vector:  ['well-received']
# processed line:  well-regarded
# feature vector:  ['well-regarded']
# processed line:  well-rounded
# feature vector:  ['well-rounded']
# processed line:  well-run
# feature vector:  ['well-run']
# processed line:  well-wishers
# feature vector:  ['well-wishers']
# processed line:  wellbeing
# feature vector:  ['wellbeing']
# processed line:  whoa
# feature vector:  ['whoa']
# processed line:  wholeheartedly
# feature vector:  ['wholeheartedly']
# processed line:  wholesome
# feature vector:  ['wholesome']
# processed line:  whooa
# feature vector:  ['whooa']
# processed line:  whoooa
# feature vector:  ['whooa']
# processed line:  wieldy
# feature vector:  ['wieldy']
# processed line:  willing
# feature vector:  ['willing']
# processed line:  willingly
# feature vector:  ['willingly']
# processed line:  willingness
# feature vector:  ['willingness']
# processed line:  win
# feature vector:  ['win']
# processed line:  windfall
# feature vector:  ['windfall']
# processed line:  winnable
# feature vector:  ['winnable']
# processed line:  winner
# feature vector:  ['winner']
# processed line:  winners
# feature vector:  ['winners']
# processed line:  winning
# feature vector:  ['winning']
# processed line:  wins
# feature vector:  ['wins']
# processed line:  wisdom
# feature vector:  ['wisdom']
# processed line:  wise
# feature vector:  ['wise']
# processed line:  wisely
# feature vector:  ['wisely']
# processed line:  witty
# feature vector:  ['witty']
# processed line:  won
# feature vector:  ['won']
# processed line:  wonder
# feature vector:  ['wonder']
# processed line:  wonderful
# feature vector:  ['wonderful']
# processed line:  wonderfully
# feature vector:  ['wonderfully']
# processed line:  wonderous
# feature vector:  ['wonderous']
# processed line:  wonderously
# feature vector:  ['wonderously']
# processed line:  wonders
# feature vector:  ['wonders']
# processed line:  wondrous
# feature vector:  ['wondrous']
# processed line:  woo
# feature vector:  ['woo']
# processed line:  work
# feature vector:  ['work']
# processed line:  workable
# feature vector:  ['workable']
# processed line:  worked
# feature vector:  ['worked']
# processed line:  works
# feature vector:  ['works']
# processed line:  world-famous
# feature vector:  ['world-famous']
# processed line:  worth
# feature vector:  ['worth']
# processed line:  worth-while
# feature vector:  ['worth-while']
# processed line:  worthiness
# feature vector:  ['worthiness']
# processed line:  worthwhile
# feature vector:  ['worthwhile']
# processed line:  worthy
# feature vector:  ['worthy']
# processed line:  wow
# feature vector:  ['wow']
# processed line:  wowed
# feature vector:  ['wowed']
# processed line:  wowing
# feature vector:  ['wowing']
# processed line:  wows
# feature vector:  ['wows']
# processed line:  yay
# feature vector:  ['yay']
# processed line:  youthful
# feature vector:  ['youthful']
# processed line:  zeal
# feature vector:  ['zeal']
# processed line:  zenith
# feature vector:  ['zenith']
# processed line:  zest
# feature vector:  ['zest']
# processed line:  zippy
# feature vector:  ['zippy']
# [(['good', 'excellent', 'value'], 1.0), (['great', 'jawbone'], 1.0), (['tied', 'charger', 'conversations', 'lasting', 'more', '45', 'minutes.major', 'problems!!'], 0.0), (['mic', 'great'], 1.0), (['i', 'jiggle', 'plug', 'get', 'line', 'up', 'right', 'get', 'decent', 'volume'], 0.0), (['you', 'several', 'dozen', 'several', 'hundred', 'contacts', 'imagine', 'fun', 'sending', 'each', 'one', 'one'], 0.0), (['you', 'razr', 'owner..you', 'must', 'this!'], 1.0), (['needless', 'i', 'wasted', 'money'], 0.0), (['what', 'waste', 'money', 'time!'], 0.0), (['sound', 'quality', 'great'], 1.0), (['impressed', 'when', 'original', 'battery', 'extended', 'battery'], 1.0), (['seperated', 'mere', '5+', 'ft', 'i', 'started', 'notice', 'excessive', 'static', 'garbled', 'sound', 'headset'], 0.0), (['good', 'quality', 'though'], 1.0), (['design', 'odd', 'ear', 'clip', 'not', 'not_very', 'not_comfortable', 'not_at', 'not_all'], 0.0), (['highly', 'recommend', 'one', 'who', 'blue', 'tooth', 'phone'], 1.0), (['i', 'advise', 'everyone', 'not', 'not_be', 'not_fooled!'], 0.0), (['far', 'good!'], 1.0), (['works', 'great!'], 1.0), (['clicks', 'makes', 'you', 'wonder', 'long', 'mechanism', 'last'], 0.0), (['i', "motorola's", 'website', 'followed', 'directions', 'not', 'not_get', 'not_it', 'not_to', 'not_pair', 'not_again'], 0.0), (['i', 'bought', 'kindle', 'fire', 'absolutely', 'loved', 'it!'], 1.0), (['commercials', 'most', 'misleading'], 0.0), (['i', 'yet', 'run', 'new', 'battery', 'below', 'bars', "that's", 'days', 'without', 'charging'], 1.0), (['i', 'bought', 'mother', 'problem', 'battery'], 0.0), (['great', 'pocket', 'pc', '/', 'phone', 'combination'], 1.0), (["i've", 'owned', 'phone', '7', 'months', "it's", 'best', 'mobile', 'phone', "i've"], 1.0), (['i', "didn't", 'not_think', 'not_that', 'not_the', 'not_instructions', 'not_provided', 'not_were', 'not_helpful', 'not_to', 'not_me'], 0.0), (['people', 'couldnt', 'hear', 'talk', 'i', 'pull', 'earphone', 'talk', 'phone'], 0.0), (["doesn't", 'not_hold', 'not_charge'], 0.0), (['simple', 'little', 'phone', 'breakage', 'unacceptible'], 0.0), (['product', 'ideal', 'people', 'like', 'whose', 'ears', 'sensitive'], 1.0), (['unusable', 'moving', 'car', 'freeway', 'speed'], 0.0), (['i', 'more', 'years', 'left', 'contract', 'i', 'hate', 'phone'], 0.0), (['car', 'charger', 'well', 'ac', 'charger', 'included', 'you', 'never', 'run', 'juice.highy', 'recommended'], 1.0), (['you', 'need', 'least', '3', 'mins', 'get', 'phone', 'book', 'time', 'you', 'first', 'turn', 'phone.battery', 'life', 'short'], 0.0), (['kept', 'up', 'well'], 1.0), (['poor', 'talk', 'time', 'performance'], 0.0), (['great', 'works', 'fine', '680'], 1.0), (['worthless', 'product'], 0.0), (['great', 'camera', 'thats', '2mp', 'pics', 'nice', 'clear', 'great', 'picture', 'quality'], 1.0), (['i', 'not', 'not_impressed', 'not_by', 'not_this', 'not_product'], 0.0), (['nice', 'headset', 'priced', 'right'], 1.0), (['i', 'only', 'hear', 'garbage', 'audio'], 0.0), (['excellent', 'bluetooth', 'headset'], 1.0), (['features', 'i', 'want'], 1.0), (['who', 'right', 'mind', 'gonna', 'buy', 'battery'], 0.0), (['arguing', 'verizon', 'regarding', 'dropped', 'calls', 'returned', 'phones', 'days'], 0.0), (['seems', 'well'], 1.0), (['disappointed', 'battery'], 0.0), (['not', 'not_loud', 'not_enough', 'not_and', "not_doesn't", 'not_turn', 'not_on', 'not_like', 'not_it', 'not_should'], 0.0), (['good', 'protection', 'not', 'not_make', 'not_phone', 'not_too', 'not_bulky'], 1.0), (['usable', 'keyboard', 'actually', 'turns', 'pda', 'real-world', 'useful', 'machine', 'instead', 'just', 'neat', 'gadget'], 1.0), (['phone', 'pretty', 'sturdy', "i've", 'never', 'large', 'problems'], 1.0), (['i', 'love', 'thing!'], 1.0), (['everything', 'fine', 'reasonable', 'price', 'i.e'], 1.0), (['disappointed'], 0.0), (['i', 'even', 'dropped', 'phone', 'stream', 'submerged', '15', 'seconds', 'still', 'works', 'great!'], 1.0), (['i', 'happy', '510', 'no', 'complaints', 'one', 'regarding', 'sound', 'q ...

# %%
def extract_features(line):
    line_words = set(line)
    features = {}
    for word in featureList:
        features['contains(%s)' % word] = (word in line_words)
    return features

# %%
#remove featureList duplicates
featureList = list(set(featureList))

# %%
#extract feature vector for all tweets at once
training_set = nltk.classify.util.apply_features(extract_features, lines)

# %%
#train the classifier
NBClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
#test the classifier
score = 0
for testLine in testTuples:
    processedTestLine = processLine(testLine[0])
    result = NBClassifier.classify(extract_features(getTrainFeatureVector(processedTestLine)))
    if(result == testLine[1]):
        score += 1
    else:
        print('Line: ', testLine)
        print('Classifier: ', result)
        print('Acutally: ', testLine[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b438673e48de> in <module>()
#       1 #test the classifier
#       2 score = 0
# ----> 3 for testLine in testTuples:
#       4     processedTestLine = processLine(testLine[0])
#       5     result = NBClassifier.classify(extract_features(getTrainFeatureVector(processedTestLine)))
#
# NameError: name 'testTuples' is not defined

# %%
accuracy = score/len(testTuples)
print(accuracy)
# Out:
# 0.9351184346035015

# %%
savedClassifier = open('savedNBClassifier.pkl', 'wb')
pickle.dump(NBClassifier, savedClassifier)
savedClassifier.close()

# %%
savedClassifier = open('savedNBClassifier.pkl', 'rb')
classer = pickle.load(savedClassifier)
savedClassifier.close()

# %%
tLine = "he was not sick"
processedTestLine = processLine(tLine)
result = classer.classify(extract_features(getFeatureVector(processedTestLine)))
print('Classifier: ', result)
# Out:
# Classifier:  0.0
